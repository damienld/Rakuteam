# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from os import listdir
from os.path import isfile, join

import PIL
from PIL import Image

# %%
class_data = pd.read_excel("/Users/ayseaylinkaya/Desktop/Datascientist/2 Project Rakuten/Class_analysis_image.xlsx")

# %%
class_data.drop(['Unnamed: 9'], axis=1)
# Out:
#     Rank  Classe  NombreElements  \
# 0     12      10            3116
# 1     16      40            2508
# 2     20      50            1681
# 3     23      60             832
# 4     14    1140            2671
# 5     10    1160            3953
# 6     27    1180             803
# 7      6    1280            4870
# 8     19    1281            2070
# 9      3    1300            5045
# 10    25    1301             807
# 11    18    1302            2491
# 12    11    1320            3241
# 13     2    1560            5073
# 14     9    1920            4303
# 15    26    1940             803
# 16     4    2060            4993
# 17    24    2220             824
# 18     8    2280            4760
# 19     7    2403            4774
# 20    21    2462            1421
# 21     5    2522            4989
# 22    15    2582            2589
# 23     1    2583           10209
# 24    17    2585            2496
# 25    13    2705            2761
# 26    22    2905             872
#
#                                                   Nom     Blanc      Noir  \
# 0   LITTERATURE/ROMANS: livres d occasions?? [à vé...  0.446384  0.009475
# 1                           JEUX VIDEOS: import slmt?  0.473008  0.010235
# 2   Acessoires pour JEUX VIDEOS! et consoles??(non...  0.541937  0.006835
# 3                                    CONSOLES de jeux  0.447811  0.009602
# 4               FIGURINES/MANGAS/UNIVERS FANTASTIQUES  0.508225  0.006417
# 5                   CARTES collection: cartes pokemon  0.394803  0.004779
# 6                            JEUX DE GUERRE sur TABLE  0.451595  0.003903
# 7                JOUETS ENFANTS: peluche, puzzle, DIY  0.453874  0.004390
# 8             JEUX EDUCATIFS ENFANTS, jeux de cartes   0.441863  0.006471
# 9   JEUX MINIATURES, radio commandés: drone, maque...  0.513673  0.006641
# 10  VETEMENTS ENFANTS/BEBE: (billard???, babyfoot???)  0.510117  0.002175
# 11  LOISIRS/EQUIPEMENT extérieur: camping, pêche, ...  0.525611  0.008326
# 12                                  BEBES accessoires  0.489158  0.004368
# 13  MAISON: cusine, fournitures, mobiliers, rangement  0.477421  0.003934
# 14  LITERIE, TEXTILE MAISON: eqipements intérieur,...  0.322192  0.008748
# 15                   ALIMENTATIONS, CONFISERIES, CAFE  0.545409  0.006333
# 16                                   LUMINAIRES, DECO  0.328828  0.013231
# 17                   Accessoires ANIMAUX domestiques   0.533149  0.004795
# 18              MAGASINES/REVUES d'ARTS et SPECTACLES  0.435789  0.003083
# 19   LIVRES MAGASINES: histoire, info, musées, spirou  0.319316  0.003913
# 20  JEUX VIDEOS OCASSIONS (Acessoires/jeux par LOT...  0.340726  0.004764
# 21             FOURNITURE de BUREAU: cahiers, carnets  0.553008  0.005561
# 22  MOBILIER extérieur et accessoires extérieur ma...  0.466371  0.007111
# 23                    PISCINE: piscine et accessoires  0.579508  0.003441
# 24                                     OUTILS JARDINS  0.563404  0.004857
# 25                             ROMAN: livre histoire?  0.669290  0.008009
# 26                 Jeux PC (en TELECHARGEMENT ou pas)  0.630324  0.012919
#
#              R           G           B
# 0   196.518350  189.668004  181.446701
# 1   188.988801  183.619281  179.766862
# 2   198.779796  196.199174  195.407933
# 3   192.768904  189.281101  188.787452
# 4   200.828538  195.193835  191.740965
# 5   182.043666  176.767507  170.529569
# 6   190.047650  185.431614  181.350853
# 7   201.414075  194.978948  190.365770
# 8   196.918476  190.376583  184.089469
# 9   199.363322  196.663637  195.741570
# 10  252.757612  252.706628  252.664224
# 11  206.230580  202.251523  199.203870
# 12  212.954636  208.976897  207.004689
# 13  210.097192  204.789808  201.922046
# 14  194.063334  185.428405  179.968530
# 15  214.349306  205.896247  198.179298
# 16  185.499234  178.448102  173.980503
# 17  210.703365  205.124100  202.386165
# 18  195.886675  189.277178  182.635228
# 19  174.865981  164.963075  158.467833
# 20  169.373563  161.705078  155.681222
# 21  218.836466  214.762874  211.568728
# 22  202.224993  199.653917  194.772481
# 23  206.741823  211.319401  212.720218
# 24  210.341622  208.508508  205.558651
# 25  219.881707  215.700007  212.826043
# 26  200.143562  197.131754  194.937020

# %%
sns.catplot(y = 'Classe', x='Blanc', color='w', edgecolor='k', kind='bar', orient = 'h', data=class_data)
plt.title("Pourcentage des pixels blancs sur les images")
plt.savefig("Pourcentage des pixels blancs sur les images.png", bbox_inches = "tight");

# %%
sns.catplot(y = 'Classe', x='Noir', color='k', kind='bar', orient = 'h', data=class_data)
plt.title("Pourcentage des pixels noirs sur les images");
plt.savefig("Pourcentage des pixels noirs sur les images.png", bbox_inches = "tight");

# %%
sns.catplot(y = 'Classe', x='R', color='r', kind='bar', orient = 'h', data=class_data)
plt.title("Moyenne de valeur R sur les images")
plt.xlim(150, 255);
plt.savefig("Moyenne de valeur R sur les images.png", bbox_inches = "tight");

# %%
sns.catplot(y = 'Classe', x='G', color='g', kind='bar', orient = 'h', data=class_data)
plt.title("Moyenne de valeur G sur les images")
plt.xlim(150, 255);
plt.savefig("Moyenne de valeur G sur les images.png", bbox_inches = "tight");

# %%
sns.catplot(y = 'Classe', x='B', color='b', kind='bar', orient = 'h', data=class_data)
plt.title("Moyenne de valeur B sur les images")
plt.xlim(150, 255);
plt.savefig("Moyenne de valeur B sur les images.png", bbox_inches = "tight");
